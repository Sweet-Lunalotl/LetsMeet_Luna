# %%
import pandas as pd
from sqlalchemy import create_engine, text

engine = create_engine("postgresql+pg8000://user:secret@127.0.0.1:5432/lf8_lets_meet_db")

with engine.begin() as conn:
    print("verbunden mit:", conn.execute(text("SELECT current_database()")).scalar())
# Out:
# <jemalloc>: Unsupported system page size
# verbunden mit: lf8_lets_meet_db

# %%
# %load_ext sql
# %config SqlMagic.displaycon = False
# %sql postgresql+pg8000://user:secret@127.0.0.1:5432/lf8_lets_meet_db
# Out:
# Connecting to 'postgresql+pg8000://user:***@127.0.0.1:5432/lf8_lets_meet_db'

# %%
df = pd.read_excel("../Lets Meet DB Dump.xlsx")
df[["Nachname", "Vorname"]] = df["Nachname, Vorname"].str.split(", ", expand=True)
df = df.drop(columns = ["Nachname, Vorname"])

# %%
#df[["Straße Nr", "PLZ", "Ort"]] = df["Straße Nr, PLZ Ort"].str.split(", ", expand=True)
# funktioniert nicht....
# schauen wir was im Rest ist
split_cols = df["Straße Nr, PLZ Ort"].str.split(", ", expand=True)
df[["Straße Nr", "PLZ", "Ort", "Rest"]] = split_cols
len(df.dropna())
# 3 mal gibt es noch etwas zusätzliches
df["Rest"].dropna()
# 3 mal wird hinter der Stadt noch "Hansestadt" angegeben. Das kann sicher entfert werden
df = df.drop(columns = ["Rest", "Straße Nr, PLZ Ort"])

# %%
df.info()
df.head()
df["E-Mail"].value_counts()[df["E-Mail"].value_counts() > 1]
df["Interessiert an"].unique()
df["Geschlecht (m/w/nonbinary)"].unique()
mask = df["Telefon"].str.contains(r'0800', na=False)
print(df[mask]["Telefon"])
shortest_phone = df["Telefon"].str.len().idxmin()
print(df.loc[shortest_phone, "Telefon"])
df["Telefon"].value_counts()[df["Telefon"].value_counts() > 1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1576 entries, 0 to 1575
# Data columns (total 11 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Telefon                                                                          1576 non-null   object
#  1   Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;  1566 non-null   object
#  2   E-Mail                                                                           1576 non-null   object
#  3   Geschlecht (m/w/nonbinary)                                                       1576 non-null   object
#  4   Interessiert an                                                                  1576 non-null   object
#  5   Geburtsdatum                                                                     1576 non-null   object
#  6   Nachname                                                                         1576 non-null   object
#  7   Vorname                                                                          1576 non-null   object
#  8   Straße Nr                                                                        1576 non-null   object
#  9   PLZ                                                                              1576 non-null   object
#  10  Ort                                                                              1576 non-null   object
# dtypes: object(11)
# memory usage: 135.6+ KB
# Series([], Name: Telefon, dtype: object)
# 02372 8020
# Series([], Name: count, dtype: int64)

# %%
df["Telefon"] = df["Telefon"].str.replace(r'[^0-9]', '', regex=True)
df["Telefon"]
shortest_phone = df["Telefon"].str.len().idxmin()
print(df.loc[shortest_phone, "Telefon"])
# Out:
# 04774716

# %%
df["Geburtsdatum"] = pd.to_datetime(df["Geburtsdatum"], format="%d.%m.%Y").dt.normalize()
df["Geburtsdatum"]
# Out:
# 0      1959-03-07
# 1      1958-02-28
# 2      1996-07-27
# 3      1992-12-09
# 4      1983-06-13
#           ...
# 1571   1989-07-08
# 1572   1984-08-05
# 1573   1977-07-12
# 1574   1978-03-22
# 1575   1970-08-19
# Name: Geburtsdatum, Length: 1576, dtype: datetime64[ns]

# %%
df["Prios"] = df["Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;"].str.replace(r'[^0-9;%]', '', regex=True)
split_prios = df["Prios"].str.split(";%", expand=True)
df[["Prio1", "Prio2", "Prio3", "Prio4", "Prio5"]] = split_prios
df["Prio1"] = df["Prio1"].str.replace(r'[^0-9]', '', regex=True)
df["Prio2"] = df["Prio2"].str.replace(r'[^0-9]', '', regex=True)
df["Prio3"] = df["Prio3"].str.replace(r'[^0-9]', '', regex=True)
df["Prio4"] = df["Prio4"].str.replace(r'[^0-9]', '', regex=True)
df["Prio5"] = df["Prio5"].str.replace(r'[^0-9]', '', regex=True)
df
# Out:
#          Telefon  \
# 0      023728020
# 1     0622198689
# 2     0383422951
# 3     0162249788
# 4     0763167955
# ...          ...
# 1571  0939187584
# 1572  0303957993
# 1573   041140577
# 1574  0819431701
# 1575  0518188107
#
#      Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;  \
# 0     Fremdsprachenkenntnisse erweitern %78%; Im Was...
# 1     Für jemanden kochen %57%; Mir die Probleme von...
# 2     In der Stadt herumbummeln %94%; Mit Freunden z...
# 3     An einer Gruppenreise teilnehmen %97%; Seine f...
# 4     Ins Grüne fahren %23%; Holz hacken %67%; Fotos...
# ...                                                 ...
# 1571  Computerspiele spielen %6%; Stricken, Häkeln, ...
# 1572  Seiner Familie etwas kaufen %46%; Über sein Ho...
# 1573  Ein Konzert, eine Opern- oder Ballettaufführun...
# 1574  Jemanden telefonisch zu einem Treffen einladen...
# 1575  Zu einer Party gehen %35%; Jemandem behilflich...
#
#                                E-Mail Geschlecht (m/w/nonbinary)  \
# 0              martin.forster@web.ork                          m
# 1          tsanaklidou.elina@1mal1.te                          w
# 2             şahin.vildan@gmaiil.ork                          w
# 3               ellen.bäumker@web.ork                          w
# 4        bekiroğlu.bahadır@autluuk.te                          m
# ...                               ...                        ...
# 1571   burkhard.wiesner@d-ohnline.ork                          m
# 1572     klaus.hesselmann@ge-em-ix.te                          m
# 1573      elisabeth.proll@autluuk.kom                          w
# 1574  marieluise.wünnemann@gmaiil.ork                          w
# 1575          frank.meyer@ge-em-ix.te                          m
#
#      Interessiert an Geburtsdatum    Nachname      Vorname  \
# 0                  w   1959-03-07     Forster       Martin
# 1                  m   1958-02-28       Elina  Tsanaklidou
# 2                  m   1996-07-27      Vildan        şahin
# 3                  m   1992-12-09     Bäumker        Ellen
# 4                  w   1983-06-13     Bahadır    Bekiroğlu
# ...              ...          ...         ...          ...
# 1571               w   1989-07-08     Wiesner     Burkhard
# 1572               w   1984-08-05  Hesselmann        Klaus
# 1573               m   1977-07-12       Proll    Elisabeth
# 1574               m   1978-03-22   Wünnemann  Marie Luise
# 1575               w   1970-08-19       Meyer        Frank
#
#                       Straße Nr    PLZ             Ort                 Prios  \
# 0            Minslebener Str. 0  46286         Dorsten  %78%;%80%;%61%;%17%;
# 1                  Gartenweg 13  69126      Heidelberg  %57%;%21%;%53%;%25%;
# 2     Heinrich-Heine-Straße 99c  17489      Greifswald  %94%;%20%;%12%;%72%;
# 3                 Weidenring 39  81539         München       %97%;%91%;%93%;
# 4          Eichendorffstraße 20  79379  Müllheim Baden  %23%;%67%;%84%;%69%;
# ...                         ...    ...             ...                   ...
# 1571             Wilhelmstr. 58  88175       Scheidegg             %6%;%21%;
# 1572            Barbyer Str. 79  10369          Berlin  %46%;%85%;%70%;%16%;
# 1573               Hauptstr. 96  30952      Ronnenberg  %25%;%36%;%26%;%67%;
# 1574           Witts Allee 59 a  92360      Mühlhausen  %59%;%67%;%41%;%11%;
# 1575            Friedensstr. 81  24568   Kaltenkirchen  %35%;%82%;%67%;%69%;
#
#      Prio1 Prio2 Prio3 Prio4 Prio5
# 0       78    80    61    17  None
# 1       57    21    53    25  None
# 2       94    20    12    72  None
# 3       97    91    93  None  None
# 4       23    67    84    69  None
# ...    ...   ...   ...   ...   ...
# 1571     6    21  None  None  None
# 1572    46    85    70    16  None
# 1573    25    36    26    67  None
# 1574    59    67    41    11  None
# 1575    35    82    67    69  None
#
# [1576 rows x 17 columns]

# %%
df["Hobbies"] = df["Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;"].str.replace(r'[%0-9]', '', regex=True)

split_hobbies = df["Hobbies"].str.split(" ; ", expand=True)
df[["Hobby1", "Hobby2", "Hobby3", "Hobby4", "Hobby5", "Hobby6"]] = split_hobbies


unique_hobbies = set()
for col in ['Hobby1', 'Hobby2', 'Hobby3', 'Hobby4', 'Hobby5', 'Hobby6']:
    unique_hobbies.update(df[col].dropna().unique())

print(len(unique_hobbies))

print(df["Hobby1"].nunique())
print(df["Hobby6"].nunique())
df = df.drop(columns=['Hobby6'])
# Out:
# 221
# 218
# 1

# %%
ls_unique_hobbies = list(unique_hobbies)
ls_unique_hobbies.remove('')
ls_unique_hobbies
df_unique_hobbies = pd.DataFrame(ls_unique_hobbies, columns=['beschreibung'])
df_unique_hobbies.reset_index(drop=True)
df_unique_hobbies.index += 1
df_unique_hobbies
# Out:
#                                  beschreibung
# 1                 Ein Musikinstrument spielen
# 2                           E-Mails schreiben
# 3                        Einfach alleine sein
# 4                          Kochen oder backen
# 5                               Zeitung lesen
# ..                                        ...
# 216  Kegeln oder einen Gymnastikkurs besuchen
# 217          Malen, basteln, musizieren, usw.
# 218          Etwas lernen und mich fortbilden
# 219      Sich politisch oder sozial betätigen
# 220              Sich um neue Arbeit bewerben
#
# [220 rows x 1 columns]

# %%
df["Interessiert an nb"]=True
df["Interessiert an m"] = df["Interessiert an"].isin(["m", "mw"])
df["Interessiert an w"] = df["Interessiert an"].isin(["w", "mw"])

# %%
df[df["Interessiert an"] == "mw"]
# Out:
#          Telefon  \
# 9     0751787178
# 81    0984073727
# 159   0544512746
# 165   0375157754
# 176   0222725840
# 179   0160449153
# 187   0212776944
# 196   0568382639
# 221   0393159860
# 287   0507538915
# 450   0338180602
# 483   0231473335
# 494   0241850556
# 584   0355692429
# 609   0728936774
# 623    033842242
# 664   0160167203
# 702    023333621
# 814   0415772770
# 880   0302035418
# 884   0201129596
# 918   0540246008
# 1031  0622343238
# 1048  0416241569
# 1100  0607228132
# 1112  0205351643
# 1153   020956813
# 1173  0853392732
# 1271   025133581
# 1412  0521216095
# 1455  0509532608
# 1538  0235906087
# 1570  0886129063
#
#      Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;  \
# 9     Etwas fertig stellen %95%; Blumen kaufen %48%;...
# 81    Stricken, Häkeln, Sticken oder Nähen %14%; Etw...
# 159   Reiten %18%; Meine Arbeit geschickt ausführen ...
# 165   Skilaufen %35%; Im Wasser waten %60%; Sich ber...
# 176   Sich um Zimmerpflanzen kümmern %10%; Ein Nicke...
# 179   Ein Konzert, eine Opern- oder Ballettaufführun...
# 187   Auf mich zukommende Situationen in Gedanken be...
# 196   Sich im Freien aufhalten (im Park, Garten etc....
# 221   Verwandte besuchen %8%; Andere Leute betrachte...
# 287   Verwandte besuchen %6%; Gegenstände reparieren...
# 450   Sich um neue Arbeit bewerben %15%; Antiquitäte...
# 483   Mit Fremden ins Gespräch kommen %14%; Mit Beka...
# 494   Etwas verleihen %91%; Mit Freunden oder Bekann...
# 584   Mit jemandem zusammen sein, den man mag %15%; ...
# 609   Sich im Freien aufhalten (im Park, Garten etc....
# 623   Meine Arbeit geschickt ausführen %47%; Die Bib...
# 664   Bowling spielen %4%; Computer-Netzwerk-Partys ...
# 702   Eine Blume oder Pflanze sehen oder daran riech...
# 814   In ein Lokal gehen %100%; Gemeinsam Probleme l...
# 880                 Post lesen %83%; Ausschlafen %72%;
# 884   Videos ansehen %84%; Eine Blume oder Pflanze s...
# 918   An einem Treffen oder einer Feier der Familie ...
# 1031  Freunde besuchen %45%; Mit Freunden zusammen s...
# 1048  Sich beruflich engagieren %89%; Etwas schmackh...
# 1100  Tanzen %67%; Fernsehen %56%; Für einen guten Z...
# 1112  In einem Chor singen %89%; Positive Zukunftspl...
# 1153  Jemanden telefonisch zu einem Treffen einladen...
# 1173  Zu einer Sportveranstaltung gehen %55%; chille...
# 1271  Mit jemandem zusammen sein, den man mag %86%; ...
# 1412  Einen Vergnügungspark besuchen %88%; Computers...
# 1455                        Aufräumen und putzen %94%;
# 1538  Mit meiner Meinung Recht haben %32%; Abends se...
# 1570  Kräuter/Pilze sammeln %57%; Zeitschriften durc...
#
#                                  E-Mail Geschlecht (m/w/nonbinary)  \
# 9     tatjana.stockbrink@iunitimail.kom                          w
# 81                insa.woelke@gmaiil.te                          w
# 159               maria.peters@1mal1.te                          w
# 165     christian.knobloch@d-ohnline.te                          m
# 176             irmgard.dube@gmaiil.kom                          w
# 179            elisabeth.arens@a-o-l.te                          w
# 187         wernher.burnus@d-ohnline.te                          m
# 196             guido.pilz@d-ohnline.te                          m
# 221          karin.kösters@d-ohnline.te                          w
# 287            udo.lensker@ge-em-ix.ork                          m
# 450            horváth.tibor@autluuk.te                          m
# 483         stefan.essling@d-ohnline.te                          m
# 494               wénfū.mián@autluuk.te                          w
# 584          oliver.kanzog@d-ohnline.te                          m
# 609       holger.steinbach@d-ohnline.te                          m
# 623         rosemarie.jethon@gmaiil.ork                          w
# 664               hubert.appel@a-o-l.te                          m
# 702         gerlind.feuerhahn@1mal1.kom                          w
# 814     christiane.richter@d-ohnline.te                          w
# 880     fritz.hengelbrock@d-ohnline.ork                          m
# 884            hedwig.berg@d-ohnline.te                          w
# 918        paolamaria.olschowka@web.ork                          w
# 1031          eckhard.wagner@autluuk.te                          m
# 1048         bernd.roelfs@iunitimail.te                          m
# 1100          matthias.vandülmen@web.te                          m
# 1112     antonioj..böhnke@d-ohnline.kom                          m
# 1153          josef.bratz@d-ohnline.ork                          m
# 1173             edzard.zeuch@gmaiil.te                          m
# 1271              ursula.gehlen@web.ork                          w
# 1412      christiane.morsch@ge-em-ix.te                          w
# 1455        martha.lorenz@d-ohnline.kom                          w
# 1538           ralf.fischer@autluuk.kom                          m
# 1570    polishchuk.eduard@d-ohnline.ork                          m
#
#      Interessiert an Geburtsdatum     Nachname      Vorname  \
# 9                 mw   1995-07-30   Stockbrink      Tatjana
# 81                mw   1970-12-13       Woelke         Insa
# 159               mw   1988-06-30       Peters        Maria
# 165               mw   1959-11-29     Knobloch    Christian
# 176               mw   1981-04-17         Dube      Irmgard
# 179               mw   1991-02-21        Arens    Elisabeth
# 187               mw   1967-06-07       Burnus      Wernher
# 196               mw   1986-01-28         Pilz        Guido
# 221               mw   1984-05-08      Kösters        Karin
# 287               mw   1969-12-08      Lensker          Udo
# 450               mw   1988-04-30        Tibor      Horváth
# 483               mw   1970-11-29      Essling       Stefan
# 494               mw   1979-11-23         Mián        Wénfū
# 584               mw   1998-01-03       Kanzog       Oliver
# 609               mw   1987-09-13    Steinbach       Holger
# 623               mw   1973-12-29       Jethon    Rosemarie
# 664               mw   1989-02-22        Appel       Hubert
# 702               mw   1981-10-29    Feuerhahn      Gerlind
# 814               mw   1971-08-03      Richter   Christiane
# 880               mw   1984-03-22  Hengelbrock        Fritz
# 884               mw   1982-08-02         Berg       Hedwig
# 918               mw   1995-01-26    Olschowka  Paola Maria
# 1031              mw   1979-05-16       Wagner      Eckhard
# 1048              mw   1985-01-20       Roelfs        Bernd
# 1100              mw   1959-11-09   van Dülmen     Matthias
# 1112              mw   2001-11-12       Böhnke   Antonio J.
# 1153              mw   1996-04-06        Bratz        Josef
# 1173              mw   2001-05-13        Zeuch       Edzard
# 1271              mw   1960-03-29       Gehlen       Ursula
# 1412              mw   1962-04-17       Morsch   Christiane
# 1455              mw   1985-08-24       Lorenz       Martha
# 1538              mw   1959-09-02      Fischer         Ralf
# 1570              mw   1971-09-16       Eduard   Polishchuk
#
#                         Straße Nr    PLZ  ... Prio5  \
# 9           Isolde-Kurz-Str. 126C  35394  ...  None
# 81                  Wasserstr. 45  81677  ...  None
# 159                Färbergasse 96  23812  ...  None
# 165             Am Gradeberg 83 c   7747  ...    85
# 176                Philippstr. 79  53359  ...  None
# 179         Hermann-Löns-Str. 84A  31241  ...  None
# 187            Lerchenstieg 56-57  42699  ...  None
# 196              Görlitzer Str 78  27729  ...  None
# 221             Breslauer-Str. 63  18437  ...  None
# 287   Bürgermeister-Fuchs-Str. 79  20257  ...  None
# 450              Mörikestraße 128  14776  ...  None
# 483            Liegnitzer Str. 48  44319  ...  None
# 494                 Bachstraße 95  52066  ...  None
# 584        Albrecht-Dürer-Str 125   4600  ...  None
# 609                 Untergath 105  74255  ...  None
# 623                Blumenweg 42 b  16928  ...  None
# 664                Puttschen 73 c  56070  ...    42
# 702               Rumfordstr. 107  58256  ...  None
# 814                   Haagstr. 93  29323  ...  None
# 880            Am Meikenhof 118 c  13156  ...  None
# 884         Luruper Hauptstr. 105  45128  ...  None
# 918                Engerstr. 32 c  23566  ...  None
# 1031               Voigtwiese 129  76534  ...  None
# 1048               Hermannstr. 14  31246  ...  None
# 1100            Thörener Str. 103  71720  ...  None
# 1112           Max-Koska-Str. 57A  45964  ...  None
# 1153            Mettmanner Str. 4  46147  ...  None
# 1173        Wolfenbütteler Str. 8  92507  ...  None
# 1271                Papendamm 88A  52062  ...  None
# 1412               Grimsehlstr. 3  28197  ...  None
# 1455          Diakonissenstr. 50A  21509  ...  None
# 1538    Lion-Feuchtwanger-Str. 78  44879  ...  None
# 1570            Weinbergstraße 75  86956  ...  None
#
#                                                 Hobbies  \
# 9     Etwas fertig stellen ; Blumen kaufen ; Etwas l...
# 81    Stricken, Häkeln, Sticken oder Nähen ; Etwas l...
# 159   Reiten ; Meine Arbeit geschickt ausführen ; Üb...
# 165   Skilaufen ; Im Wasser waten ; Sich beruflich e...
# 176   Sich um Zimmerpflanzen kümmern ; Ein Nickerche...
# 179   Ein Konzert, eine Opern- oder Ballettaufführun...
# 187   Auf mich zukommende Situationen in Gedanken be...
# 196   Sich im Freien aufhalten (im Park, Garten etc....
# 221   Verwandte besuchen ; Andere Leute betrachten ;...
# 287   Verwandte besuchen ; Gegenstände reparieren ; ...
# 450   Sich um neue Arbeit bewerben ; Antiquitäten re...
# 483   Mit Fremden ins Gespräch kommen ; Mit Bekannte...
# 494   Etwas verleihen ; Mit Freunden oder Bekannten ...
# 584   Mit jemandem zusammen sein, den man mag ; Sich...
# 609   Sich im Freien aufhalten (im Park, Garten etc....
# 623   Meine Arbeit geschickt ausführen ; Die Bibel o...
# 664   Bowling spielen ; Computer-Netzwerk-Partys ; F...
# 702   Eine Blume oder Pflanze sehen oder daran riech...
# 814   In ein Lokal gehen ; Gemeinsam Probleme lösen ...
# 880                         Post lesen ; Ausschlafen ;
# 884   Videos ansehen ; Eine Blume oder Pflanze sehen...
# 918   An einem Treffen oder einer Feier der Familie ...
# 1031   Freunde besuchen ; Mit Freunden zusammen sein ;
# 1048  Sich beruflich engagieren ; Etwas schmackhafte...
# 1100  Tanzen ; Fernsehen ; Für einen guten Zweck spe...
# 1112  In einem Chor singen ; Positive Zukunftspläne ...
# 1153  Jemanden telefonisch zu einem Treffen einladen...
# 1173  Zu einer Sportveranstaltung gehen ; chillen ; ...
# 1271  Mit jemandem zusammen sein, den man mag ; Comp...
# 1412  Einen Vergnügungspark besuchen ; Computerspiel...
# 1455                            Aufräumen und putzen ;
# 1538  Mit meiner Meinung Recht haben ; Abends seinem...
# 1570  Kräuter/Pilze sammeln ; Zeitschriften durchblä...
#
#                                                  Hobby1  \
# 9                                  Etwas fertig stellen
# 81                 Stricken, Häkeln, Sticken oder Nähen
# 159                                              Reiten
# 165                                           Skilaufen
# 176                      Sich um Zimmerpflanzen kümmern
# 179   Ein Konzert, eine Opern- oder Ballettaufführun...
# 187   Auf mich zukommende Situationen in Gedanken be...
# 196     Sich im Freien aufhalten (im Park, Garten etc.)
# 221                                  Verwandte besuchen
# 287                                  Verwandte besuchen
# 450                        Sich um neue Arbeit bewerben
# 483                     Mit Fremden ins Gespräch kommen
# 494                                     Etwas verleihen
# 584             Mit jemandem zusammen sein, den man mag
# 609     Sich im Freien aufhalten (im Park, Garten etc.)
# 623                    Meine Arbeit geschickt ausführen
# 664                                     Bowling spielen
# 702    Eine Blume oder Pflanze sehen oder daran riechen
# 814                                  In ein Lokal gehen
# 880                                          Post lesen
# 884                                      Videos ansehen
# 918   An einem Treffen oder einer Feier der Familie ...
# 1031                                   Freunde besuchen
# 1048                          Sich beruflich engagieren
# 1100                                             Tanzen
# 1112                               In einem Chor singen
# 1153     Jemanden telefonisch zu einem Treffen einladen
# 1173                  Zu einer Sportveranstaltung gehen
# 1271            Mit jemandem zusammen sein, den man mag
# 1412                     Einen Vergnügungspark besuchen
# 1455                               Aufräumen und putzen
# 1538                     Mit meiner Meinung Recht haben
# 1570                              Kräuter/Pilze sammeln
#
#                                                  Hobby2  \
# 9                                         Blumen kaufen
# 81                     Etwas lernen und mich fortbilden
# 159                    Meine Arbeit geschickt ausführen
# 165                                     Im Wasser waten
# 176                               Ein Nickerchen machen
# 179                                Mich laut beschweren
# 187
# 196                           Streit aus dem Wege gehen
# 221                             Andere Leute betrachten
# 287                              Gegenstände reparieren
# 450        Antiquitäten restaurieren, Möbel aufarbeiten
# 483                          Mit Bekannten telefonieren
# 494          Mit Freunden oder Bekannten zusammen essen
# 584                           Sich beruflich engagieren
# 609                     Für sich selbst Dinge einkaufen
# 623     Die Bibel oder andere religiöse Schriften lesen
# 664                            Computer-Netzwerk-Partys
# 702                      Etwas planen oder organisieren
# 814                            Gemeinsam Probleme lösen
# 880                                         Ausschlafen
# 884    Eine Blume oder Pflanze sehen oder daran riechen
# 918        Einfach mit guten Freunden zwanglos plaudern
# 1031                         Mit Freunden zusammen sein
# 1048                  Etwas schmackhaftes zu mir nehmen
# 1100                                          Fernsehen
# 1112                   Positive Zukunftspläne schmieden
# 1153                                        Radio hören
# 1173                                            chillen
# 1271                             Computerspiele spielen
# 1412                             Computerspiele spielen
# 1455
# 1538  Abends seinem Partner Ereignisse des Tages erz...
# 1570                  Zeitschriften durchblättern/lesen
#
#                                                  Hobby3  \
# 9                      Etwas lernen und mich fortbilden
# 81
# 159          Über die Probleme anderer Leute nachdenken
# 165                           Sich beruflich engagieren
# 176
# 179                                         Musik hören
# 187                                                None
# 196         Kreuzworträtsel lösen oder ein Puzzle legen
# 221                  Mich meinen Wunschträumen hingeben
# 287                                         Ausschlafen
# 450
# 483
# 494           Seine finanziellen Angelegenheiten regeln
# 584                Stricken, Häkeln, Sticken oder Nähen
# 609                                  Tagebuch schreiben
# 623
# 664                                   Für andere sorgen
# 702
# 814                          Mit Bekannten telefonieren
# 880
# 884                          Mit Bekannten telefonieren
# 918          Über die Probleme anderer Leute nachdenken
# 1031
# 1048  Private Sachen erledigen, die schon lange lieg...
# 1100                      Für einen guten Zweck spenden
# 1112
# 1153                Die Sterne oder den Mond beobachten
# 1173                                      Barfuß laufen
# 1271                               Einfach alleine sein
# 1412  Private Sachen erledigen, die schon lange lieg...
# 1455                                               None
# 1538                  Nur so herumsitzen und nachdenken
# 1570    Die Bibel oder andere religiöse Schriften lesen
#
#                                                  Hobby4  \
# 9
# 81                                                 None
# 159                              Frische Luft schnappen
# 165                                       Blumen kaufen
# 176                                                None
# 179   Private Sachen erledigen, die schon lange lieg...
# 187                                                None
# 196                    Positive Zukunftspläne schmieden
# 221
# 287
# 450                                                None
# 483                                                None
# 494                       Für einen guten Zweck spenden
# 584                                         Ausschlafen
# 609                       Für einen guten Zweck spenden
# 623                                                None
# 664                                       Zeitung lesen
# 702                                                None
# 814
# 880                                                None
# 884
# 918   Private Sachen erledigen, die schon lange lieg...
# 1031                                               None
# 1048
# 1100
# 1112                                               None
# 1153
# 1173       Antiquitäten restaurieren, Möbel aufarbeiten
# 1271  Auf mich zukommende Situationen in Gedanken be...
# 1412
# 1455                                               None
# 1538
# 1570
#
#                                                  Hobby5 Interessiert an nb  \
# 9                                                  None               True
# 81                                                 None               True
# 159                                                                   True
# 165   Romane, Erzählungen, Theaterstücke oder Gedich...               True
# 176                                                None               True
# 179                                                                   True
# 187                                                None               True
# 196                                                                   True
# 221                                                None               True
# 287                                                None               True
# 450                                                None               True
# 483                                                None               True
# 494                                                                   True
# 584                                                                   True
# 609                                                                   True
# 623                                                None               True
# 664                    Etwas lernen und mich fortbilden               True
# 702                                                None               True
# 814                                                None               True
# 880                                                None               True
# 884                                                None               True
# 918                                                                   True
# 1031                                               None               True
# 1048                                               None               True
# 1100                                               None               True
# 1112                                               None               True
# 1153                                               None               True
# 1173                                                                  True
# 1271                                                                  True
# 1412                                               None               True
# 1455                                               None               True
# 1538                                               None               True
# 1570                                               None               True
#
#      Interessiert an m Interessiert an w
# 9                 True              True
# 81                True              True
# 159               True              True
# 165               True              True
# 176               True              True
# 179               True              True
# 187               True              True
# 196               True              True
# 221               True              True
# 287               True              True
# 450               True              True
# 483               True              True
# 494               True              True
# 584               True              True
# 609               True              True
# 623               True              True
# 664               True              True
# 702               True              True
# 814               True              True
# 880               True              True
# 884               True              True
# 918               True              True
# 1031              True              True
# 1048              True              True
# 1100              True              True
# 1112              True              True
# 1153              True              True
# 1173              True              True
# 1271              True              True
# 1412              True              True
# 1455              True              True
# 1538              True              True
# 1570              True              True
#
# [33 rows x 26 columns]

# %%
df.dtypes
# Out:
# Telefon                                                                                    object
# Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;            object
# E-Mail                                                                                     object
# Geschlecht (m/w/nonbinary)                                                                 object
# Interessiert an                                                                            object
# Geburtsdatum                                                                       datetime64[ns]
# Nachname                                                                                   object
# Vorname                                                                                    object
# Straße Nr                                                                                  object
# PLZ                                                                                        object
# Ort                                                                                        object
# Prios                                                                                      object
# Prio1                                                                                      object
# Prio2                                                                                      object
# Prio3                                                                                      object
# Prio4                                                                                      object
# Prio5                                                                                      object
# Hobbies                                                                                    object
# Hobby1                                                                                     object
# Hobby2                                                                                     object
# Hobby3                                                                                     object
# Hobby4                                                                                     object
# Hobby5                                                                                     object
# Interessiert an nb                                                                           bool
# Interessiert an m                                                                            bool
# Interessiert an w                                                                            bool
# dtype: object

# %%
shortest_hobby = df["Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;"].str.len().idxmin()
print(df.loc[shortest_hobby, "Hobby1 %Prio1%; Hobby2 %Prio2%; Hobby3 %Prio3%; Hobby4 %Prio4%; Hobby5 %Prio5%;"])
# Out:
# Beten %34%;

# %%
df.reset_index(drop=True)
df.index +=1

# %%
DDL_KUNDE = """
CREATE TABLE kunde (
    kunde_id int PRIMARY KEY,
    name text NOT NULL,
    vorname text NOT NULL,
    email text NOT NULL UNIQUE,
    telefon text,
    geschlecht text NOT NULL,
    geburtsdatum date NOT NULL
)
"""

DDL_INTERESSE ="""
CREATE TABLE interesse (
    interesse_id serial PRIMARY KEY,
    kunde_id integer REFERENCES kunde (kunde_id),
    maennlich boolean NOT NULL,
    weiblich boolean NOT NULL,
    nonbinary boolean NOT NULL    
)
"""

DDL_ADRESSE="""
CREATE TABLE adresse (
    adresse_id serial PRIMARY KEY,
    kunde_id integer REFERENCES kunde (kunde_id),
    strasse_nummer text NOT NULL,
    plz text NOT NULL,
    ort text NOT NULL
)
"""

DLL_HOBBY="""
CREATE TABLE hobby (
    hobby_id int PRIMARY KEY,
    beschreibung text NOT NULL
)
"""

DLL_HOBBY_KUNDE="""
CREATE TABLE hobby_kunde (
    kunde_id integer REFERENCES kunde (kunde_id),
    hobby_id integer REFERENCES hobby (hobby_id),
    prio integer NOT NULL,
    CONSTRAINT pk_hobby_kunde PRIMARY KEY (kunde_id, hobby_id)
)
"""


with engine.begin() as conn:
    conn.execute(text("DROP TABLE IF EXISTS hobby_kunde"))
    conn.execute(text("DROP TABLE IF EXISTS interesse"))
    conn.execute(text("DROP TABLE IF EXISTS adresse CASCADE"))
    conn.execute(text("DROP TABLE IF EXISTS hobby"))
    conn.execute(text("DROP TABLE IF EXISTS kunde"))
    conn.execute(text(DDL_KUNDE))
    conn.execute(text(DLL_HOBBY))
    conn.execute(text(DDL_ADRESSE))
    conn.execute(text(DDL_INTERESSE))
    conn.execute(text(DLL_HOBBY_KUNDE))

print("Tabellen angelegt")
# Out:
# Tabellen angelegt

# %%
# Kunde-Tabelle

kunde_data = df[["Nachname", "Vorname", "E-Mail", "Telefon", "Geschlecht (m/w/nonbinary)", "Geburtsdatum"]].copy()
kunde_data.columns = ["name", "vorname", "email", "telefon", "geschlecht", "geburtsdatum"]
kunde_data.to_sql("kunde", engine, if_exists="append", index=True, index_label="kunde_id")
# Out:
# 1576

# %%
# %%sql
# SELECT * from KUNDE
# Out:
# 1576 rows affected.
# +----------+------------+-------------+-----------------------------------+------------+------------+--------------+
# | kunde_id |    name    |   vorname   |               email               |  telefon   | geschlecht | geburtsdatum |
# +----------+------------+-------------+-----------------------------------+------------+------------+--------------+
# |    1     |  Forster   |    Martin   |       martin.forster@web.ork      | 023728020  |     m      |  1959-03-07  |
# |    2     |   Elina    | Tsanaklidou |     tsanaklidou.elina@1mal1.te    | 0622198689 |     w      |  1958-02-28  |
# |    3     |   Vildan   |    şahin    |      şahin.vildan@gmaiil.ork      | 0383422951 |     w      |  1996-07-27  |
# |    4     |  Bäumker   |    Ellen    |       ellen.bäumker@web.ork       | 0162249788 |     w      |  1992-12-09  |
# |    5     |  Bahadır   |  Bekiroğlu  |    bekiroğlu.bahadır@autluuk.te   | 0763167955 |     m      |  1983-06-13  |
# |    6     |    Fink    |  Karl-Heinz |    karl-heinz.fink@ge-em-ix.kom   | 0235530742 |     m      |  1980-08-07  |
# |    7     |   Gövert   |     Dirk    |      dirk.gövert@autluuk.ork      | 0271300135 |     m      |  1983-04-18  |
# |    8     |   Rüsing   |     Paul    |       paul.rüsing@1mal1.kom       | 0425196481 |     m      |  1967-01-19  |
# |    9     | Wiesnewski |     Tim     |    tim.wiesnewski@d-ohnline.te    | 0939218291 |     m      |  1968-02-21  |
# |    10    | Stockbrink |   Tatjana   | tatjana.stockbrink@iunitimail.kom | 0751787178 |     w      |  1995-07-30  |
# +----------+------------+-------------+-----------------------------------+------------+------------+--------------+
# Truncated to displaylimit of 10.

# %%
# Adresse-Tabelle
adresse_data = df[["Straße Nr", "PLZ", "Ort"]].copy()
adresse_data.columns = ["strasse_nummer", "plz", "ort"]
adresse_data.to_sql("adresse", engine, if_exists="append", index=True, index_label="kunde_id")
# Out:
# 1576

# %%
# %%sql
# SELECT * from adresse
# Out:
# 1576 rows affected.
# +------------+----------+---------------------------+-------+----------------+
# | adresse_id | kunde_id |       strasse_nummer      |  plz  |      ort       |
# +------------+----------+---------------------------+-------+----------------+
# |     1      |    1     |     Minslebener Str. 0    | 46286 |    Dorsten     |
# |     2      |    2     |        Gartenweg 13       | 69126 |   Heidelberg   |
# |     3      |    3     | Heinrich-Heine-Straße 99c | 17489 |   Greifswald   |
# |     4      |    4     |       Weidenring 39       | 81539 |    München     |
# |     5      |    5     |    Eichendorffstraße 20   | 79379 | Müllheim Baden |
# |     6      |    6     |        Lindenweg 80       | 44795 |     Bochum     |
# |     7      |    7     |     Rahlenbeckstr. 100    | 56070 |    Koblenz     |
# |     8      |    8     |       Im Brückle 44       | 33334 |   Gütersloh    |
# |     9      |    9     |       Wilhelmsaue 29      | 88131 |     Lindau     |
# |     10     |    10    |   Isolde-Kurz-Str. 126C   | 35394 |     Gießen     |
# +------------+----------+---------------------------+-------+----------------+
# Truncated to displaylimit of 10.

# %%
# intresse Tabbel
interesse_data = df[["Interessiert an nb", "Interessiert an m", "Interessiert an w"]].copy()
interesse_data.columns = ["nonbinary", "maennlich", "weiblich"]
interesse_data.to_sql("interesse", engine, if_exists="append", index=True, index_label="kunde_id")
# Out:
# 1576

# %%
# %%sql
# select * from interesse
# Out:
# 1576 rows affected.
# +--------------+----------+-----------+----------+-----------+
# | interesse_id | kunde_id | maennlich | weiblich | nonbinary |
# +--------------+----------+-----------+----------+-----------+
# |      1       |    1     |   False   |   True   |    True   |
# |      2       |    2     |    True   |  False   |    True   |
# |      3       |    3     |    True   |  False   |    True   |
# |      4       |    4     |    True   |  False   |    True   |
# |      5       |    5     |   False   |   True   |    True   |
# |      6       |    6     |   False   |   True   |    True   |
# |      7       |    7     |   False   |   True   |    True   |
# |      8       |    8     |   False   |   True   |    True   |
# |      9       |    9     |   False   |   True   |    True   |
# |      10      |    10    |    True   |   True   |    True   |
# +--------------+----------+-----------+----------+-----------+
# Truncated to displaylimit of 10.

# %%
df_unique_hobbies.to_sql("hobby", engine, if_exists="append", index=True, index_label="hobby_id")
# Out:
# 220

# %%
# %%sql
# select * from hobby
# Out:
# 220 rows affected.
# +----------+-----------------------------------------+
# | hobby_id |               beschreibung              |
# +----------+-----------------------------------------+
# |    1     |       Ein Musikinstrument spielen       |
# |    2     |            E-Mails schreiben            |
# |    3     |           Einfach alleine sein          |
# |    4     |            Kochen oder backen           |
# |    5     |              Zeitung lesen              |
# |    6     |              Tennis spielen             |
# |    7     |   Zu kirchlichen Veranstaltungen gehen  |
# |    8     |                  Beten                  |
# |    9     |                Fernsehen                |
# |    10    | Mit Kindern gemeinsam etwas unternehmen |
# +----------+-----------------------------------------+
# Truncated to displaylimit of 10.

# %%
#hobby_kunde_data = pd.DataFrame(columns=["kunde_id", "hobby_id", "prio"])

# %%
hobby_kunde_data = []

for idx, row in df.iterrows():
    for i in range(1, 6):
        hobby_col = f"Hobby{i}"
        prio_col = f"Prio{i}"
        if pd.notna(row[hobby_col]) and pd.notna(row[prio_col]):
            hobby_kunde_data.append({
                "kunde_id": idx,
                "hobby_id": df_unique_hobbies[df_unique_hobbies["beschreibung"] == row[hobby_col]].index[0],
                "prio": int(row[prio_col])
            })

hobby_kunde_df = pd.DataFrame(hobby_kunde_data)
hobby_kunde_df.to_sql("hobby_kunde", engine, if_exists="append", index=False)
# Out:
# 4828

# %%
# %%sql
# select * from hobby_kunde
# Out:
# 4828 rows affected.
# +----------+----------+------+
# | kunde_id | hobby_id | prio |
# +----------+----------+------+
# |    1     |   135    |  78  |
# |    1     |    11    |  80  |
# |    1     |    14    |  61  |
# |    1     |   164    |  17  |
# |    2     |   137    |  57  |
# |    2     |   186    |  21  |
# |    2     |   193    |  53  |
# |    2     |   132    |  25  |
# |    3     |   191    |  94  |
# |    3     |   134    |  20  |
# +----------+----------+------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# select * from hobby_kunde as hk
# join kunde as k on k.kunde_id = hk.kunde_id
# join hobby as h on h.hobby_id = hk.hobby_id
# Out:
# 4828 rows affected.
# +----------+----------+------+------------+---------+-------------+----------------------------+------------+------------+--------------+------------+-----------------------------------------------------+
# | kunde_id | hobby_id | prio | kunde_id_1 |   name  |   vorname   |           email            |  telefon   | geschlecht | geburtsdatum | hobby_id_1 |                     beschreibung                    |
# +----------+----------+------+------------+---------+-------------+----------------------------+------------+------------+--------------+------------+-----------------------------------------------------+
# |    1     |   135    |  78  |     1      | Forster |    Martin   |   martin.forster@web.ork   | 023728020  |     m      |  1959-03-07  |    135     |          Fremdsprachenkenntnisse erweitern          |
# |    1     |    11    |  80  |     1      | Forster |    Martin   |   martin.forster@web.ork   | 023728020  |     m      |  1959-03-07  |     11     |                   Im Wasser waten                   |
# |    1     |    14    |  61  |     1      | Forster |    Martin   |   martin.forster@web.ork   | 023728020  |     m      |  1959-03-07  |     14     |              Schwierige Probleme klären             |
# |    1     |   164    |  17  |     1      | Forster |    Martin   |   martin.forster@web.ork   | 023728020  |     m      |  1959-03-07  |    164     |                Morgens Früh aufstehen               |
# |    2     |   137    |  57  |     2      |  Elina  | Tsanaklidou | tsanaklidou.elina@1mal1.te | 0622198689 |     w      |  1958-02-28  |    137     |                 Für jemanden kochen                 |
# |    2     |   186    |  21  |     2      |  Elina  | Tsanaklidou | tsanaklidou.elina@1mal1.te | 0622198689 |     w      |  1958-02-28  |    186     |         Mir die Probleme von anderen anhören        |
# |    2     |   193    |  53  |     2      |  Elina  | Tsanaklidou | tsanaklidou.elina@1mal1.te | 0622198689 |     w      |  1958-02-28  |    193     | Abends seinem Partner Ereignisse des Tages erzählen |
# |    2     |   132    |  25  |     2      |  Elina  | Tsanaklidou | tsanaklidou.elina@1mal1.te | 0622198689 |     w      |  1958-02-28  |    132     |            Für einen guten Zweck spenden            |
# |    3     |   191    |  94  |     3      |  Vildan |    şahin    |  şahin.vildan@gmaiil.ork   | 0383422951 |     w      |  1996-07-27  |    191     |              In der Stadt herumbummeln              |
# |    3     |   134    |  20  |     3      |  Vildan |    şahin    |  şahin.vildan@gmaiil.ork   | 0383422951 |     w      |  1996-07-27  |    134     |              Mit Freunden zusammen sein             |
# +----------+----------+------+------------+---------+-------------+----------------------------+------------+------------+--------------+------------+-----------------------------------------------------+
# Truncated to displaylimit of 10.

# %%
# die obere Abfrage zeigt, dass alles noch funktioniert

# %%
# %%sql
# create view migration_users as
# select k.email, k.vorname, k.name, k.geburtsdatum, a.plz, a.ort from kunde as k
# join adresse as a on a.kunde_id = k.kunde_id
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from migration_users
# Out:
# 1576 rows affected.
# +-----------------------------------+-------------+------------+--------------+-------+----------------+
# |               email               |   vorname   |    name    | geburtsdatum |  plz  |      ort       |
# +-----------------------------------+-------------+------------+--------------+-------+----------------+
# |       martin.forster@web.ork      |    Martin   |  Forster   |  1959-03-07  | 46286 |    Dorsten     |
# |     tsanaklidou.elina@1mal1.te    | Tsanaklidou |   Elina    |  1958-02-28  | 69126 |   Heidelberg   |
# |      şahin.vildan@gmaiil.ork      |    şahin    |   Vildan   |  1996-07-27  | 17489 |   Greifswald   |
# |       ellen.bäumker@web.ork       |    Ellen    |  Bäumker   |  1992-12-09  | 81539 |    München     |
# |    bekiroğlu.bahadır@autluuk.te   |  Bekiroğlu  |  Bahadır   |  1983-06-13  | 79379 | Müllheim Baden |
# |    karl-heinz.fink@ge-em-ix.kom   |  Karl-Heinz |    Fink    |  1980-08-07  | 44795 |     Bochum     |
# |      dirk.gövert@autluuk.ork      |     Dirk    |   Gövert   |  1983-04-18  | 56070 |    Koblenz     |
# |       paul.rüsing@1mal1.kom       |     Paul    |   Rüsing   |  1967-01-19  | 33334 |   Gütersloh    |
# |    tim.wiesnewski@d-ohnline.te    |     Tim     | Wiesnewski |  1968-02-21  | 88131 |     Lindau     |
# | tatjana.stockbrink@iunitimail.kom |   Tatjana   | Stockbrink |  1995-07-30  | 35394 |     Gießen     |
# +-----------------------------------+-------------+------------+--------------+-------+----------------+
# Truncated to displaylimit of 10.
